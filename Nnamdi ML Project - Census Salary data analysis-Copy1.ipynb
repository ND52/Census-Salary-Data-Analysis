# %%
#Importing Required Libraries for processing and Data Visualisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#dealing with warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
Salaries = pd.read_csv(r"C:\Users\CELEBOBO COMPUTERS\Downloads\census_salary.csv")

#Having a look at the dataset
Salaries
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#making a copy of the dataset
Salaries2 = Salaries.copy()

#Size of dataset
Salaries2.shape
# Out:
# (32561, 15)

# %%
#a brief summary of the dataset
Salaries2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#statistical summary of the data
Salaries2.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#checking for missing/null values
Salaries2.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
#checking for duplicates
Salaries2.duplicated().sum()
# Out:
# 24

# %%
#removing duplicate values
Salaries2.drop_duplicates(keep='first',inplace=True)

Salaries2.shape
# Out:
# (32537, 15)

# %%
#renaming the sex column to gender and fnlwgt to final_weight
Salaries2.rename(columns={'fnlwgt': 'final_weight', 'sex': 'gender'}, inplace=True)
Salaries2.head(10)
# Out:
#    age          workclass  final_weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
# 5   37            Private        284582     Masters             14
# 6   49            Private        160187         9th              5
# 7   52   Self-emp-not-inc        209642     HS-grad              9
# 8   31            Private         45781     Masters             14
# 9   42            Private        159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#Getting the unique values of the Object Columns/categorical features to check for missing values and errors
for x in Salaries2.columns:
    if Salaries2[x].dtype=='object':
        print()
        print(x)
        print(Salaries2[x].unique())
# Out:
# workclass
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# education
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# marital-status
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# occupation
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
#
# relationship
# [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
#
# race
# [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
#
# gender
# [' Male' ' Female']
#
# ...

# %%
#replacing the Columns with ' ?' symbol with "nan" for effective analysis
Salaries2.replace(' ?', np.nan, inplace=True)

Salaries2.head(28)
# Out:
#     age          workclass  final_weight      education  education-num  \
# 0    39          State-gov         77516      Bachelors             13
# 1    50   Self-emp-not-inc         83311      Bachelors             13
# 2    38            Private        215646        HS-grad              9
# 3    53            Private        234721           11th              7
# 4    28            Private        338409      Bachelors             13
# 5    37            Private        284582        Masters             14
# 6    49            Private        160187            9th              5
# 7    52   Self-emp-not-inc        209642        HS-grad              9
# 8    31            Private         45781        Masters             14
# 9    42            Private        159449      Bachelors             13
# 10   37            Private        280464   Some-college             10
# 11   30          State-gov        141297      Bachelors             13
# ...

# %%
#checking for columns with null(nan) values

Salaries2.isna().sum()
# Out:
# age                  0
# workclass         1836
# final_weight         0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# gender               0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     582
# salary               0
# dtype: int64

# %%
#replacing the nan values with "other" as the values in the columns are not related and i cant create values on my own
Salaries2[['workclass', 'occupation', 'native-country']] = Salaries2[['workclass','occupation', 'native-country']].fillna(value='other')

#checking for the alterations
Salaries3 = Salaries2.iloc[27:, [1,6]]
Salaries3
# Out:
#            workclass          occupation
# 27             other               other
# 28           Private     Exec-managerial
# 29           Private        Craft-repair
# 30         Local-gov     Protective-serv
# 31           Private               Sales
# ...              ...                 ...
# 32556        Private        Tech-support
# 32557        Private   Machine-op-inspct
# 32558        Private        Adm-clerical
# 32559        Private        Adm-clerical
# 32560   Self-emp-inc     Exec-managerial
#
# [32510 rows x 2 columns]

# %%
#checking for columns with null(nan) values

Salaries2.isna().sum()
# Out:
# age               0
# workclass         0
# final_weight      0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# gender            0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# ## DATA EXPLORATION

# %%
sns.set_style('darkgrid')

#Total count of persons by salary 

# Create two countplots
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize=(15, 8))

# Create the first countplot with total count
ax = sns.countplot(x="salary", palette={'blue', 'green'}, ax=ax1, data=Salaries2)

# Create the second countplot with percent by total
ax = sns.countplot(x="salary", data=Salaries2, palette={'blue', 'green'}, ax=ax2)

#set the titles of the plots
c
ax2.set_title("Total count of persons by salary in %")

# Calculate the percentage by total and Add annotations for percents and totals on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    height = p.get_height()
    ax2.text(p.get_x()+p.get_width()/2., height + 3, '{:.1f}%'.format((height/total)*100), ha="center")
    ax1.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.100, p.get_height()+30))    

plt.show()

# %% [markdown]
# . The plot shows that majority of the Individuals earn salaries <=50k; Only 24% of the individuals earn salaries >50k

# %%
#salary by gender
fig, axs = plt.subplots(nrows=2, ncols=2 , figsize=(15, 15))

#create 1st plot with total count of gender in units
ax = sns.countplot(x='gender', palette={'blue','green'}, data=Salaries2, ax=axs[0][0])

# Create the 2nd countplot with total count of gender by salary in units
ax = sns.countplot(x="gender",  palette={'blue','green'}, hue = "salary", data=Salaries2, ax=axs[0][1])

# Create the 3rd countplot with total count of gender in %
ax = sns.countplot(x="gender", palette={'blue','green'}, data=Salaries2, ax=axs[1][0])

# Create the 3rd countplot with total count of gender by salary in %
ax = sns.countplot(x="gender",  palette={'blue','green'}, hue = "salary", data=Salaries2, ax=axs[1][1])

#set the titles of the plots
axs[0][0].set_title("Total Count of gender in units")
axs[0][1].set_title("gender by salary in units")
axs[1][0].set_title("Total count of gender in %")
axs[1][1].set_title("gender by salary in %")


# Calculate percentages by total and Add annotations for percents and totals on top of bars
total = int(len(Salaries2))

for p in axs[0][0].patches:
    axs[0][0].annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+50))
for p in axs[0][1].patches:
    axs[0][1].annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+50))
for p in axs[1][0].patches:
    height = p.get_height()
    axs[1][0].text(p.get_x()+p.get_width()/2., height + 6, '{:.1f}%'.format((height/total)*100), ha="center")
for p in axs[1][1].patches:
    height = p.get_height()
    axs[1][1].text(p.get_x()+p.get_width()/2., height + 6, '{:.1f}%'.format((height/total)*100), ha="center")
    
plt.show()

# %% [markdown]
# . the plot shows that men accounts for 66% of total individual records compared to women
# . Also there are few women earning salaries >50k compared to men.

# %%
#Total count of individuals by native country
plt.figure(figsize=(15, 8))
ax = sns.countplot(data=Salaries2, y = 'native-country')
sns.set_palette('Accent_r')
ax.set_title('individuals by native country')
# Out:
# Text(0.5, 1.0, 'individuals by native country')

# %% [markdown]
# Almost 90% of individuals are from United States

# %%
#Salary by work class
plt.subplots(figsize = (15,8))

ax = sns.countplot(x="workclass", hue = "salary", palette={'blue', 'green'}, data=Salaries2)

ax.set_title("workclass by salary in units")
# Calculate the total and Add annotations for the totals on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+60))
    
plt.xticks(rotation=45, ha='right');

# %%
plt.subplots(figsize = (15,8))
ax = sns.countplot(x="workclass", hue="salary", palette={'blue', 'green'}, data=Salaries2)

ax.set_title("workclass by salary in %")
# Calculate the percentage and annotate the percents on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2., height + 6, '{:.1f}%'.format((height/total)*100), ha="center")
plt.xticks(rotation=45, ha='right');
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# . Private workers accounts for greater number of individuals
# . Also majority of the private workers earn salaries >50k compared to other workclass
# . also >50k is higher than <=50k in self employed workers

# %%
#Salary by Education
plt.subplots(figsize = (15,8))
ax = sns.countplot(y="education", hue="salary", palette={'blue', 'green'}, data=Salaries2)

# %%
plt.subplots(figsize = (15,8))
ax = sns.countplot(x="education", hue="salary", palette={'blue', 'green'}, data=Salaries2)

ax.set_title("education by salary in %")
# Calculate the percentage and annotate the percents on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2., height + 6, '{:.1f}%'.format((height/total)*100), ha="center")
plt.xticks(rotation=45, ha='right');
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# . There are more Highschool graduates followed by Some-college and Bachelors degree workers
# . >50k salary is greater than <=50k salary in Masters degree, Doctorate and Professional school employees

# %%
#Salary by Occupation
plt.subplots(figsize = (15,8))
ax = sns.countplot(x="occupation", hue="salary", palette={'blue', 'green'}, data=Salaries2)
ax.set_title("occupation by salary in units")
# Calculate the total and annotate the totals on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+60))
    
plt.xticks(rotation=45, ha='right');

# %%
plt.subplots(figsize = (15,8))
ax = sns.countplot(x="occupation", hue="salary", palette={'blue', 'green'}, data=Salaries2)

ax.set_title("occupation by salary in %")
# Calculate the percentage and annotate the percents on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2., height + 6, '{:.1f}%'.format((height/total)*100), ha="center")
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# . there are more prof specialty, followed by Craft repairs, Executive managerial, Admin clerical and Sales employees
# . <=50k is greater than >50k in all the employees

# %%
#Salary by Race
plt.subplots(figsize = (15,8))

ax = sns.countplot(x="race", hue="salary", palette={'blue', 'green'}, data=Salaries2)

ax.set_title("race by salary in units")

#Calculate the total and Annotate the totals on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+60))

# %%
colors = ['blue', 'red', 'brown', 'yellow', 'green']
plt.title('total count of race in %')

Salaries2.groupby("race").salary.count().plot(kind='pie', ylabel='', colors=colors,  legend= 'race', autopct='%1.1f%%')
plt.legend(bbox_to_anchor= (1.05, 1), loc='upper left', borderaxespad=3)
plt.show()

# %% [markdown]
# . there is greater percentage of White employees followed by Blacks
# . <=50k is higher than >50k in all the races

# %%
#Salary by Marital status
plt.subplots(figsize = (15,8))

ax = sns.countplot(x="marital-status", hue="salary", palette={'blue', 'green'}, data=Salaries2)

ax.set_title("Marital Status by salary in units")

#Calculate the total and annotate the  totals on top of bars
total = int(len(Salaries2))
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+60))

# %%
colors = ['blue', 'red', 'brown', 'yellow', 'green', 'purple', 'turquoise', 'white']
plt.title('total count of marital status in %')

Salaries2.groupby("marital-status").salary.count().plot(kind='pie', ylabel='', colors=colors,  legend= 'marital-status', autopct='%1.1f%%')
plt.legend(bbox_to_anchor= (1.05, 1), loc='upper left', borderaxespad=3)
plt.show()

# %% [markdown]
# . There are more Married people followed by Never-married and Divorced
# . Married-civ-spouse earn higher salaries >50k compared to other marital status

# %%
#Age and hours distribution
data = Salaries2[['age', 'hours-per-week']]

# create outlier point shape
red_diamond = dict(markerfacecolor='r', marker='D')

# generate subplots
fig, ax = plt.subplots()

# make the boxplot
plt.boxplot(data.values, labels=['age', 'hours-per-week'], flierprops=red_diamond);

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,8))

# age distribution
ax=sns.distplot(Salaries2["age"], ax=axs[0])

#hours/week 
ax=sns.distplot(Salaries2["hours-per-week"], ax=axs[1])

# %%
#age and hour relationship
sns.lineplot(x="age", y="hours-per-week", data=Salaries2)
# Out:
# <AxesSubplot:xlabel='age', ylabel='hours-per-week'>

# %% [markdown]
# .there is noticeable number of outliers in both age and hours features
# .there is greater number of individuals between ages 30 to 50
# .greater number of individuals work between 40 to 50 hours per week
# .Individuals within the 30 to 50 age range works for more hours per week

# %%
#hours/week and gender relationship
sns.barplot(x="gender", y="hours-per-week", data=Salaries2, palette={'blue', 'green'})
# Out:
# <AxesSubplot:xlabel='gender', ylabel='hours-per-week'>

# %% [markdown]
# Men work for more hours per week compared to women

# %%
# Gender and hour relationship by salary
ax = sns.barplot(x="gender", y="hours-per-week", palette={'blue','green'}, hue="salary", data=Salaries2,)

# %% [markdown]
# men that earn >50k work for more hours in a week likewise the women

# %%
#age relationship with gender by salary
ax = sns.barplot(x="gender", y="age", palette={'blue','green'}, hue="salary", data=Salaries2,)

# %% [markdown]
# majority of older men and women earn salary above 50k

# %%
#showing the correlation in the numerical features
Salaries2.corr()
# Out:
#                      age  final_weight  education-num  capital-gain  \
# age             1.000000     -0.076447       0.036224      0.077676
# final_weight   -0.076447      1.000000      -0.043388      0.000429
# education-num   0.036224     -0.043388       1.000000      0.122664
# capital-gain    0.077676      0.000429       0.122664      1.000000
# capital-loss    0.057745     -0.010260       0.079892     -0.031639
# hours-per-week  0.068515     -0.018898       0.148422      0.078408
#
#                 capital-loss  hours-per-week
# age                 0.057745        0.068515
# final_weight       -0.010260       -0.018898
# education-num       0.079892        0.148422
# capital-gain       -0.031639        0.078408
# capital-loss        1.000000        0.054229
# hours-per-week      0.054229        1.000000

# %%
#Creating a heatmap 
plt.figure(figsize=(10, 6))
sns.heatmap(Salaries2.corr(), annot=True, cmap='Accent_r')
# Out:
# <AxesSubplot:>

# %%
#Converting the >50k salary to 1 and <=50k to 0
Salaries2['salary']=Salaries2['salary'].replace(' <=50K',0)
Salaries2['salary']=Salaries2['salary'].replace(' >50K',1)
Salaries2.head(10)
# Out:
#    age          workclass  final_weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
# 5   37            Private        284582     Masters             14
# 6   49            Private        160187         9th              5
# 7   52   Self-emp-not-inc        209642     HS-grad              9
# 8   31            Private         45781     Masters             14
# 9   42            Private        159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#individuals of age above mean age that earn above 50k
mean_age = Salaries2['age'].mean()
above_mean_age = Salaries2[Salaries2['age'] > mean_age]
salary_50k = above_mean_age[above_mean_age['salary'] == 1]
print(len(salary_50k))
# Out:
# 5298

# %%
#individuals of age above mean age that earn below 50k
salaryb_50k = above_mean_age[above_mean_age['salary'] == 0]
print(len(salaryb_50k))
# Out:
# 9747

# %% [markdown]
# There is 5298 individuals whose age is above mean age that earns salary above 50k
# And there is 9747 individuals whose age is above mean age that earns salary below 50k

# %%
#individuals of age below mean age that earn above 50k
below_mean_age = Salaries2[Salaries2['age'] < mean_age]
salaryless_50k = below_mean_age[below_mean_age['salary'] == 1]
print(len(salaryless_50k))
# Out:
# 2541

# %%
#individuals of age below mean age that earn below 50k
salary2less_50k = below_mean_age[below_mean_age['salary'] == 0]
print(len(salary2less_50k))
# Out:
# 14951

# %% [markdown]
# There is 2541 individuals whose age is below mean age that earns salary above 50k
# And there is 14951 individuals whose age is below mean age that earns salary below 50k

# %% [markdown]
# # Model building and Data preprocessing

# %%
#Importing Machine learning Models
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
#splitting the data into features and labels
X = Salaries2.drop(["salary", "final_weight", "occupation", "native-country", "relationship"], axis= "columns") # droping the label variable (salary) and other features that are not needed

y = Salaries2["salary"]

# %%
X.head()
# Out:
#    age          workclass   education  education-num       marital-status  \
# 0   39          State-gov   Bachelors             13        Never-married
# 1   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 2   38            Private     HS-grad              9             Divorced
# 3   53            Private        11th              7   Married-civ-spouse
# 4   28            Private   Bachelors             13   Married-civ-spouse
#
#      race   gender  capital-gain  capital-loss  hours-per-week
# 0   White     Male          2174             0              40
# 1   White     Male             0             0              13
# 2   White     Male             0             0              40
# 3   Black     Male             0             0              40
# 4   Black   Female             0             0              40

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: salary, dtype: int64

# %%
#One hot encoding
pd.get_dummies(X)
# Out:
#        age  education-num  capital-gain  capital-loss  hours-per-week  \
# 0       39             13          2174             0              40
# 1       50             13             0             0              13
# 2       38              9             0             0              40
# 3       53              7             0             0              40
# 4       28             13             0             0              40
# ...    ...            ...           ...           ...             ...
# 32556   27             12             0             0              38
# 32557   40              9             0             0              40
# 32558   58              9             0             0              40
# 32559   22              9             0             0              20
# 32560   52              9         15024             0              40
#
#        workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  \
# ...

# %%
#saving the result of one hot encoding
X = pd.get_dummies(X)

# %% [markdown]
# # Model Building

# %% [markdown]
# Lets use the training data to build the model and then use test data to make prediction and evaluations.
#
# we will compare the following  Machine Learning classificatoin algorithms and see how to carry out each of them, and their performance in comparison with each other:-
#
# . Logistic Regression
# . Random Forest Model
# . K-Nearest Neighbors
# . DecisionTreeClassifier
# . GradientBoostingClassifier
# . Naive Bayes Model
# . Extreme Gradient Boost (XGBoost) Model
# . Support Vector Machine (SVM)

# %%
#Splitting the data into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 1234)

# %% [markdown]
# # Logistic Regression

# %%
#Importing logistic regression from Sklearn module
from sklearn.linear_model import LogisticRegression

# %%
#training the model
l_reg = LogisticRegression()

l_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#prediction using the feature from test data
l_reg.predict(X_test)
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
#saving the prediction
logistic_prediction = l_reg.predict(X_test)

# %%
#preparing a confusion matrix to evaluate classification algorithms
def ConfusionMatrix(ytest, ypred, label = ["Negative", "Positive"]):
    
    from sklearn.metrics import confusion_matrix
   
    
    cm = confusion_matrix(ytest, ypred)
    
    plt.figure(figsize=(7, 5))
    
    sns.heatmap(cm, annot = True, cbar = False, fmt = 'd', cmap = 'Greens_r')
    
    plt.xlabel('Predicted', fontsize = 13)
    plt.xticks([0.5, 1.5], label)

    plt.yticks([0.5, 1.5], label)    
    plt.ylabel('Truth', fontsize = 13)
    
    plt.title('A confusion matrix');

# %%
ConfusionMatrix(y_test, logistic_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4594 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 800 True positives (TP): predicting that an individual will  make over 50k a year and an individual actually made over 50k a year.
#
# .There are 747 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 367 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
#Evaluation Metrics


#Checking the accuracy
Accuracy=metrics.accuracy_score(y_test, logistic_prediction)
Accuracy
# Out:
# 0.8288260602335586

# %% [markdown]
# The accuracy of the model is  82.88%

# %%
#checking the F1 score
f1score=metrics.f1_score(y_test, logistic_prediction)
f1score
# Out:
# 0.5895357406042743

# %% [markdown]
# The F1 score of the model is  58.95%

# %% [markdown]
# # Random Forest Model

# %%
#Importing Random Forest model from Sklearn module
from sklearn.ensemble import RandomForestClassifier

#training the model
randomforestmodel = RandomForestClassifier()

randomforestmodel.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#Prediction
randomforestmodel_prediction = randomforestmodel.predict(X_test)

# %%
randomforestmodel_prediction
# Out:
# array([1, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
#Model performance
ConfusionMatrix(y_test, randomforestmodel_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4535 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 955 True positives (TP): predicting that an individual will  make over 50k a year and an individual actually made over 50k a year.
#
# .There are 592 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 426 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
#Checking the accuracy
Accuracy=metrics.accuracy_score(y_test, randomforestmodel_prediction)
Accuracy
# Out:
# 0.8432698217578365

# %% [markdown]
# The accuracy of the model is 84.42%

# %%
#checking the F1 score
f1score=metrics.f1_score(y_test, randomforestmodel_prediction)
f1score
# Out:
# 0.6521145975443384

# %% [markdown]
# The F1 score of the model is 65.51%

# %% [markdown]
# # KneighborsClassifier

# %%
#Importing K-Neighborsclassifier from Sklearn module
from sklearn.neighbors import KNeighborsClassifier

#Training the model
Neighbors = KNeighborsClassifier()

Neighbors.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#prediction
Neighbors.predict(X_test)
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
Neighbors_prediction = Neighbors.predict(X_test)

# %%
#model performance
ConfusionMatrix(y_test, Neighbors_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4480 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 977 True positives (TP): predicting that an individual will  make over 50k a year and an individual actually made over 50k a year.
#
# .There are 570 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 481 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
Accuracy=metrics.accuracy_score(y_test, Neighbors_prediction)
Accuracy
# Out:
# 0.8385064535955746

# %% [markdown]
# The accuracy of the model is 83.85%

# %%
f1score=metrics.f1_score(y_test, Neighbors_prediction)
f1score
# Out:
# 0.6502495840266223

# %% [markdown]
# The F1 score of the model is 65.02%

# %% [markdown]
# # DecisionTreeClassifier

# %%
#Importing DecisionTreeClassifier from Sklearn module
from sklearn.tree import DecisionTreeClassifier

#Training the model
Decision = DecisionTreeClassifier()

Decision.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#prediction
Decision .predict(X_test)
# Out:
# array([1, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
Decision_prediction = Decision.predict(X_test)

# %%
#model performance
ConfusionMatrix(y_test, Decision_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4463 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 914 True positives (TP): predicting that an individual will  make over 50k a year and an individual actually made over 50k a year.
#
# .There are 633 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 498 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
Accuracy=metrics.accuracy_score(y_test, Decision_prediction)
Accuracy
# Out:
# 0.8254456054087277

# %% [markdown]
# The accuracy score of the model is 82.50%

# %%
f1score=metrics.f1_score(y_test, Decision_prediction)
f1score
# Out:
# 0.6177658142664872

# %% [markdown]
# The F1 score of the model is 61.61%

# %% [markdown]
# # GradientBoostingClassifier

# %%
#Importing GradientBoostingClassifier from SKlearn module
from sklearn.ensemble import GradientBoostingClassifier

#Training the model
Gradient = GradientBoostingClassifier()
Gradient.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
#prediction
Gradient .predict(X_test)
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
Gradient_prediction = Gradient.predict(X_test)

# %%
#model performance
ConfusionMatrix(y_test, Gradient_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4691 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 954 True positives (TP): predicting that an individual will make over 50k a year and an individual actually made over 50k a year.
#
# .There are 593 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 270 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
#Accuracy score
Accuracy=metrics.accuracy_score(y_test, Gradient_prediction)
Accuracy
# Out:
# 0.8673939766441303

# %% [markdown]
# The accuracy of the model is 86.73%

# %%
#f1 acore
f1score=metrics.f1_score(y_test, Gradient_prediction)
f1score
# Out:
# 0.6885600866113317

# %% [markdown]
# The f1score of the model is 68.85%

# %% [markdown]
# # Naive Bayes model

# %%
#Importing Naive Model From SKlearn module
from sklearn.naive_bayes import GaussianNB

#Training the model
naivemodel = GaussianNB()

naivemodel.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Prediction
naivemodel_prediction = naivemodel.predict(X_test)

# %%
naivemodel_prediction
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
#Model performance
ConfusionMatrix(y_test, naivemodel_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4476 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 958 True positives (TP): predicting that an individual will make over 50k a year and an individual actually made over 50k a year.
#
# .There are 589 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 485 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
#Accuracy Score
Accuracy=metrics.accuracy_score(y_test, naivemodel_prediction)
Accuracy
# Out:
# 0.8349723417332514

# %% [markdown]
# The accuracy score of the model is 83.50%

# %%
#F1 score
f1score=metrics.f1_score(y_test, naivemodel_prediction)
f1score
# Out:
# 0.6408026755852844

# %% [markdown]
# The f1 score of the model is 64.10%

# %% [markdown]
# # Extreme Gradient Boost (XGBoost) Model

# %%
#importing XGboost model from SK learn module
from xgboost import XGBClassifier

#Training the model
xgboostmodel = XGBClassifier(use_label_encoder=False)

xgbboostmodel = xgboostmodel.fit(X_train, y_train)

# %%
#Prediction
xgbboostmodel_prediction = xgboostmodel.predict(X_test)

# %%
xgbboostmodel_prediction
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
#Model performance
ConfusionMatrix(y_test, xgbboostmodel_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4647 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 1017 True positives (TP): predicting that an individual will make over 50k a year and an individual actually made over 50k a year.
#
# .There are 530 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 314 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
#Accuracy score
Accuracy=metrics.accuracy_score(y_test, xgbboostmodel_prediction)
Accuracy
# Out:
# 0.8703134603564844

# %% [markdown]
# The accuracy score of the model is 87.03%

# %%
#F1 score
f1score=metrics.f1_score(y_test, xgbboostmodel_prediction)
f1score
# Out:
# 0.7067407922168172

# %% [markdown]
# The f1 score of the model is 70.67%

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
#importing SVM model from Sklearn module
from sklearn.svm import SVC

#Training the model
SVMmodel = SVC()

SVMmodel.fit(X_train, y_train)
# Out:
# SVC()

# %%
#Prediction
SVMmodel_prediction = SVMmodel.predict(X_test)
SVMmodel_prediction
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
#Model performance
ConfusionMatrix(y_test, SVMmodel_prediction, label= ["<=50k", ">50k"])

# %% [markdown]
# .There are 4806 True Negatives (TN): predicting that an individual will not make over 50k a year and truly an individual did not make over 50k a year
#
# .There are 432 True positives (TP): predicting that an individual will make over 50k a year and an individual actually made over 50k a year.
#
# .There are 1115 False Negatives (FN): predicting that an individual will not make over 50k a year and an individual actually made over 50k a year.
#
# .There are 155 False Positives (FP): predicting that an individual will make over 50k a year and an individual did not make over 50k a year.

# %%
#Accuracy score
Accuracy=metrics.accuracy_score(y_test, SVMmodel_prediction)
Accuracy
# Out:
# 0.8048555623847572

# %% [markdown]
# The accuracy score of the model is 80.50%

# %%
#F1 score
f1score=metrics.f1_score(y_test, SVMmodel_prediction)
f1score
# Out:
# 0.40487347703842547

# %% [markdown]
# The F1 score of the model is 40.50%

# %% [markdown]
# # Visualising the accuracy & F1 score of the models

# %%
data = [['Logistic_Regression', 82.88, 58.95], ['Random_ForestClassifier',84.42, 65.51], ['KNeighbors_Classifier', 83.85, 65.02],
        ['Decision_Tree_Classifier', 82.50, 61.61], ['Gradient_Boosting_Classifier', 86.73, 68.85], 
        ['Naive Bayes', 83.50, 64.10], ['XGB_Classifier', 87.03, 70.67], ['SVC', 70.67, 40.50]] 

df = pd.DataFrame(data, columns = ['model_name', 'Model_accuracy', 'Model_F1_score']) 

df
# Out:
#                      model_name  Model_accuracy  Model_F1_score
# 0           Logistic_Regression           82.88           58.95
# 1       Random_ForestClassifier           84.42           65.51
# 2         KNeighbors_Classifier           83.85           65.02
# 3      Decision_Tree_Classifier           82.50           61.61
# 4  Gradient_Boosting_Classifier           86.73           68.85
# 5                   Naive Bayes           83.50           64.10
# 6                XGB_Classifier           87.03           70.67
# 7                           SVC           70.67           40.50

# %%
ax = sns.barplot(y="model_name", x="Model_accuracy", data=df)
ax.set_title("Accuracy of Models in %")
plt.show()
ax = sns.barplot(y="model_name", x="Model_F1_score", data=df)
ax.set_title("F1 Score of Models in %")
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Having trained all the Eight (8) models,it can be observed that the best models that can give better prediction whether an
#
# individual earns over 50k a year or not is the XGBClassifier, GradientBoostingClassifier and RandomForestModel. They have
#
# better accuracy and f1 score combination compared to other models

# %% [markdown]
# # Summary

# %% [markdown]
# . Approximately 76% of the data in this dataset earns <=50k a year
#
# . Masters degree, Doctorate and Professional school employees are most likely to earn salaries >50k
#
# . Females are more likely to be earning <= 50k
#
# . working hour of women is less when compared to men
#
# . older people are most likely to earn salary >50k compared to younger people
#
# . Younger people work for more hours than older
#
# . Approximately 53% of individuals above average age earns >50k while 98% earns <=50k
